# %%
import pandas as pd

# Ruta al archivo .conf
file_path = r'C:\Users\Lenovo\Desktop\Ironhack\FINAL PROJECT\CSVs_and EXCEL_docs\disposable_email_blocklist.conf'

# Leer el archivo y crear un DataFrame
df_suspicious_emais = pd.read_csv(file_path, header=None, names=['dominio'])

# Ver los primeros registros para asegurarte de que se leyó correctamente
df_suspicious_emais.head()
df_suspicious_emais.shape
# Out:
# (3993, 1)

# %%
# Ruta y nombre del nuevo archivo CSV donde guardarás el DataFrame
output_file_path = r'C:\Users\Lenovo\Desktop\Ironhack\FINAL PROJECT\CSVs_and EXCEL_docs\suspicious_emails.csv'

# Guardar el DataFrame en un nuevo archivo CSV
df_suspicious_emais.to_csv(output_file_path, index=False)  # Se agrega index=False para no incluir el índice en el archivo

# %%
#excluir index de dataset para que lo pueda leer big query

import pandas as pd

# Reemplaza 'archivo.csv' con el nombre de tu archivo CSV real
df = pd.read_csv(r'C:\Users\Lenovo\Desktop\Ironhack\FINAL PROJECT\CSVs_and EXCEL_docs\df_unido.csv')
df.head()
# Out:
#    customerEmail transactionId orderId paymentMethodId  \
# 0  1yf0@jedyz63t      foo56851  gcop7b       igpmsjd73
# 1  1yf0@jedyz63t      drngwa51  eftfwy       0l7kszls7
# 2  1yf0@jedyz63t      5010w1m2  1ca3sy       vej6hz0vq
# 3  1yf0@jedyz63t      xyavqxjg  1ca3sy       0l7kszls7
# 4  1yf0@jedyz63t      84xwwv0d  is64fx       igpmsjd73
#
#    paymentMethodRegistrationFailure paymentMethodType paymentMethodProvider  \
# 0                               0.0            paypal            Mastercard
# 1                               0.0              card         VISA 13 digit
# 2                               0.0              card               Maestro
# 3                               0.0              card         VISA 13 digit
# 4                               0.0            paypal            Mastercard
#
#    transactionAmount  transactionFailed orderState customerPhone  \
# 0               38.0                0.0  fulfilled  463-609-3475
# ...

# %%
df.to_csv(r'C:\Users\Lenovo\Desktop\Ironhack\FINAL PROJECT\CSVs_and EXCEL_docs\df_unido_no_index.csv', index=False)
